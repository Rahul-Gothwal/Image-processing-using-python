# %%
from skimage import io

# %%
img = io.imread("cloud.jpeg")

# %%
io.imshow(img)
io.show()

# %%
from skimage import data, color

# %%
x = data.img()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-bd8216d9467a> in <module>()
# ----> 1 x = data.img()
#
# AttributeError: 'module' object has no attribute 'img'

# %%
grayscale= color.rgb2gray(img)

# %%
io.imshow(grayscale)
io.show()

# %%
red = img[:,:,0]

# %%
io.imshow(red)
io.show()

# %%
io.imshow(img)
io.show()

# %%
img.shape
# Out:
# (458, 720, 3)

# %%
img.size
# Out:
# 989280

# %%
green = img[:,:,1]
io.imshow(green)
io.show()

# %%
blue = img[:,:,2]
io.imshow(blue)
io.show()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
ver_flip=np.flipud(img)
io.imshow(ver_flip)
io.show()

# %%
hor_flip=np.fliplr(img)
io.imshow(hor_flip)
io.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(blue.ravel(), bins=256)
plt.show()

# %%
plt.hist(red.ravel(), bins=256)
plt.show()

# %%
plt.hist(green.ravel(), bins=256)
plt.show()

# %%
from skimage.filters import sobel

# %%
edge_sobel= sobel(grayscale)#only works in 2-d array i.e. grayscale image
plot_camparison=(img, edge_sobel,"campare")

# %%
plt.show(plot_camparison)

# %%
io.imshow(edge_sobel)
io.show()

# %%
def show(img):
    io.imshow(img)
